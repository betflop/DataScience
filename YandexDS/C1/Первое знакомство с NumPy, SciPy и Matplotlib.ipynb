# %% [markdown]
# #Первое знакомство с NumPy, SciPy и Matplotlib

# %% [markdown]
# ##Numpy

# %%
import numpy as np

# %%
x = [2, 3, 4, 6]
y = np.array(x)

# %%
print type(x), x
print type(y), y
# Out:
#   File "<ipython-input-3-6fd7e3f8dc61>", line 1
#     print type(x), x
#              ^
# SyntaxError: invalid syntax

# %%
print x[1:3]
# Out:
#   File "<ipython-input-4-16d10765c2e0>", line 1
#     print x[1:3]
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(x[1:3])?

# %%
print y[1:3]
# Out:
#   File "<ipython-input-5-25024cbc825b>", line 1
#     print y[1:3]
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(y[1:3])?

# %%
print x[[0, 2]]

# %%
print y[[0, 2]]

# %%
print y[y>3]

# %%
print x * 5

# %%
print y * 5

# %%
print x ** 2

# %%
print y ** 2

# %%
matrix = [[1, 2, 4], [3, 1, 0]]
nd_array = np.array(matrix)

# %%
print matrix[1][2]

# %%
print nd_array[1, 2]

# %%
print np.random.rand()

# %%
print np.random.randn()

# %%
print np.random.randn(4)

# %%
print np.random.randn(4, 5)

# %%
print np.arange(0, 8, 0.1)

# %%
print range(0, 8, 0.1)

# %%
# %timeit np.arange(0, 10000)
# %timeit range(0, 10000)

# %% [markdown]
# ##SciPy

# %%
from scipy import optimize

# %%
def f(x):
    return (x[0] - 3.2) ** 2 + (x[1] - 0.1) ** 2 + 3

print f([3.2, 0.1])

# %%
x_min = optimize.minimize(f, [5, 5])
print x_min

# %%
print x_min.x

# %%
from scipy import linalg

# %%
a = np.array([[3, 2, 0], [1, -1, 0], [0, 5, 1]])
b = np.array([2, 4, -1])

x = linalg.solve(a, b)
print(x)
# Out:
# [ 2. -2.  9.]

# %%
print np.dot(a, x)

# %%
X = np.random.randn(4, 3)
U, D, V = linalg.svd(X)
print U.shape, D.shape, V.shape
print type(U), type(D), type(V)

# %% [markdown]
# ##Matplotlib

# %%
# %matplotlib notebook
from matplotlib import pylab as plt
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()
# Out:
# <div id='877599d0-ee68-4593-bfdd-bb84a2fc3f6d'></div>

# %%
x = np.arange(-10, 10, 0.1)
y = x ** 3
plt.plot(x, y)
plt.show();

# %% [markdown]
# ## Все вместе

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

# %%
x = np.arange(0, 10, 2)
y = np.exp(-x/3.0) + np.random.randn(len(x)) * 0.05

print (x[:5])
print (y[:5])
# Out:
# [0 2 4 6 8]
# [1.06797037 0.54406196 0.23355478 0.22162806 0.14961622]

# %%
f = interpolate.interp1d(x, y, kind='quadratic')
xnew = np.arange(0, 8, 0.1)
ynew = f(xnew)

# %%
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %%
i = 0
for n in range(51):
#     print(i)
    i = i + n
    
print(i/50.)
# Out:
# 25.5

# %%
X = [0, 0, 1, 1]
Y = [0, 1, 1, 0]
plt.plot(X, Y)
plt.show()

m = np.array([X, Y])
x = np.array([[-1, -1], [1, 3]])
g = x.dot(m)

plt.plot(g[0], g[1])
plt.show()
